# %% [markdown]
# ## This is my fisrt Jupyter Python notebook

# %%
#My first python output

print('Hello, Python!!')
# Out:
# Hello, Python!!

# %%
#Checking python version

import sys
print(sys.version)
# Out:
# 3.6.13 | packaged by conda-forge | (default, Feb 19 2021, 05:36:01)
# [GCC 9.3.0]

# %%
#Practicing writing comments

print('Hello World') #This is a comment for a line that prints a string
#print('Hello World')
# Out:
# Hello World

# %% [markdown]
# ### Errors in Python

# %%
#Print a string as error message

frint("Hello")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d0cc7f50190a> in <module>
#       1 #Print a string as error message
#       2
# ----> 3 frint("Hello")
#
# NameError: name 'frint' is not defined

# %%
#Looking at a built in error message

print('Hello World)
# Out:
#   File "<ipython-input-5-d0d52565a70f>", line 3
#     print('Hello World)
#                        ^
# SyntaxError: EOL while scanning string literal

# %%
#Print string and error message to see the running order

print('line 1')
frint('Line 2')
print('Line 3')
# Out:
# line 1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-372cd773cfb3> in <module>
#       2
#       3 print('line 1')
# ----> 4 frint('Line 2')
#       5 print('Line 3')
#
# NameError: name 'frint' is not defined

# %% [markdown]
# In the code cell below, use the print() function to print out the phrase: Hello, world!

# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# Now, let's enhance your code with a comment. In the code cell below, print out the phrase: Hello, world! and comment it with the phrase Print the traditional hello world all in one line of code.

# %%
print('Hello world') # Print the traditional hello world!!
# Out:
# Hello world

# %% [markdown]
# ### Data Types

# %%
#Integer
11
type(11) #type is an inbuilt function that returns the data type of the object
# Out:
# int

# %%
#Float
type(12.34)
# Out:
# float

# %%
#String
type("hello")
# Out:
# str

# %% [markdown]
# ### Integers

# %%
# Data type of negative numbers

type(-1)
# Out:
# int

# %%
#Data type of 0
type(0)
# Out:
# int

# %%
# Data type of positive numbers 

type(4)
# Out:
# int

# %% [markdown]
# ###  Floats

# %%
# Data type of numbers with decimal

print(type(0.1))
print(type(0.5))
print(type(0.56))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
#System settings about float type

sys.float_info
# Out:
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)

# %% [markdown]
# ### Converting from one object type to another

# %%
# Verify that this is an integer

type(2)
# Out:
# int

# %%
# Convert 2 to float

float(2)
# Out:
# 2.0

# %%
# Check the data type of 2

type(float(2))
# Out:
# float

# %%
# Casting integer 1.1 from float to cast will result in loss of information

int(1.2)
# Out:
# 1

# %%
# Convert a string to an integer

int("1")
# Out:
# 1

# %%
# Convert a string to an integer with error

int( '1 and 2')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-c8ad7bd5c3f6> in <module>
#       1 # Convert a string to an integer with error
#       2
# ----> 3 int( '1 and 2')
#
# ValueError: invalid literal for int() with base 10: '1 and 2'

# %%
# Convert "1.2" string to float

float("1.2")
# Out:
# 1.2

# %%
### Converting numbers to strings

str(1)
# Out:
# '1'

# %%
# Convert a float to string

str(1.66)
# Out:
# '1.66'

# %% [markdown]
# ### Boolean Data Type

# %%
# Value True

True
# Out:
# True

# %%
# Value False

False
# Out:
# False

# %%
# Type of Boolean

type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %% [markdown]
# ### Conver bool to int

# %%
# Convert True to int

int(True)
# Out:
# 1

# %%
# Convert False to int

int(False)
# Out:
# 0

# %% [markdown]
# ## Exercises

# %%
# What is the data type result of 6/2

# %%
#What is the data type result of 6//2

# %%
#Addition Operation

# %%
#Subtraction Operation

# %%
#Multiplication Operation

# %%
#Division Operation

# %%
#Integer Division operation

# %%
# Expression that calculates how many seconds in a minute
mins = int(input("Enter minutes"))
secs = mins * 60
print(secs)
# Out:
# Enter minutes7
# 420

# %%
# Expression to calculate how many hours in 160 mins

160/60 #For a float value
160//60 # For a integer value
# Out:
# 2

# %% [markdown]
# ### Variables

# %%
# Store value in variable

x = 43 + 44 *2 / 5
x
# Out:
# 60.6

# %%
# Name of variables meaningfully

total_hours = 45+ 66 + 10

# %%
# Using variable to perform operations

total_mins = total_hours * 60
total_mins
# Out:
# 7260
